# %%
import pandas as pd

# %%
df = pd.read_csv("depression_data.csv")
df
# Out:
#                     Name  Age Marital Status    Education Level  \
# 0       Christine Barker   31        Married  Bachelor's Degree
# 1       Jacqueline Lewis   55        Married        High School
# 2         Shannon Church   78        Widowed    Master's Degree
# 3         Charles Jordan   58       Divorced    Master's Degree
# 4           Michael Rich   18         Single        High School
# ...                  ...  ...            ...                ...
# 413763       Sean Miller   68        Married    Master's Degree
# 413764   Christina Brown   26         Single  Bachelor's Degree
# 413765   Matthew Jenkins   57        Married  Bachelor's Degree
# 413766     Gary Faulkner   71        Married   Associate Degree
# 413767    Joseph Johnson   62        Widowed    Master's Degree
#
#         Number of Children Smoking Status Physical Activity Level  \
# 0                        2     Non-smoker                  Active
# ...

# %%
df = df.iloc[:3768]
df
# Out:
#                   Name  Age Marital Status    Education Level  \
# 0     Christine Barker   31        Married  Bachelor's Degree
# 1     Jacqueline Lewis   55        Married        High School
# 2       Shannon Church   78        Widowed    Master's Degree
# 3       Charles Jordan   58       Divorced    Master's Degree
# 4         Michael Rich   18         Single        High School
# ...                ...  ...            ...                ...
# 3763     Jessica Young   60        Widowed  Bachelor's Degree
# 3764   Bryan Gutierrez   51       Divorced  Bachelor's Degree
# 3765   Timothy Jackson   41        Married  Bachelor's Degree
# 3766      Jose Johnson   53        Married        High School
# 3767     Eugene Thomas   54        Married    Master's Degree
#
#       Number of Children Smoking Status Physical Activity Level  \
# 0                      2     Non-smoker                  Active
# 1                      1     Non-smoker               Sedentary
# ...

# %%
df.head()
# Out:
#                Name  Age Marital Status    Education Level  \
# 0  Christine Barker   31        Married  Bachelor's Degree
# 1  Jacqueline Lewis   55        Married        High School
# 2    Shannon Church   78        Widowed    Master's Degree
# 3    Charles Jordan   58       Divorced    Master's Degree
# 4      Michael Rich   18         Single        High School
#
#    Number of Children Smoking Status Physical Activity Level  \
# 0                   2     Non-smoker                  Active
# 1                   1     Non-smoker               Sedentary
# 2                   1     Non-smoker               Sedentary
# 3                   3     Non-smoker                Moderate
# 4                   0     Non-smoker               Sedentary
#
#   Employment Status     Income Alcohol Consumption Dietary Habits  \
# 0        Unemployed   26265.67            Moderate       Moderate
# 1          Employed   42710.36                High      Unhealthy
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3768 entries, 0 to 3767
# Data columns (total 16 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Name                          3768 non-null   object
#  1   Age                           3768 non-null   int64
#  2   Marital Status                3768 non-null   object
#  3   Education Level               3768 non-null   object
#  4   Number of Children            3768 non-null   int64
#  5   Smoking Status                3768 non-null   object
#  6   Physical Activity Level       3768 non-null   object
#  7   Employment Status             3768 non-null   object
#  8   Income                        3768 non-null   float64
#  9   Alcohol Consumption           3768 non-null   object
#  10  Dietary Habits                3768 non-null   object
#  11  Sleep Patterns                3768 non-null   object
# ...

# %%
df.describe()
# Out:
#                Age  Number of Children         Income
# count  3768.000000         3768.000000    3768.000000
# mean     49.201168            1.289278   50475.351200
# std      18.148749            1.227796   40270.287544
# min      18.000000            0.000000      16.080000
# 25%      33.000000            0.000000   21478.855000
# 50%      50.000000            1.000000   37691.540000
# 75%      65.000000            2.000000   76357.540000
# max      80.000000            4.000000  209894.250000

# %%
df.dtypes
# Out:
# Name                             object
# Age                               int64
# Marital Status                   object
# Education Level                  object
# Number of Children                int64
# Smoking Status                   object
# Physical Activity Level          object
# Employment Status                object
# Income                          float64
# Alcohol Consumption              object
# Dietary Habits                   object
# Sleep Patterns                   object
# History of Mental Illness        object
# History of Substance Abuse       object
# Family History of Depression     object
# Chronic Medical Conditions       object
# dtype: object

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 3763    False
# 3764    False
# 3765    False
# 3766    False
# 3767    False
# Length: 3768, dtype: bool

# %%
df.drop_duplicates(inplace=True)
df
# Out:
# C:\Users\yasha\AppData\Local\Temp\ipykernel_12700\1725291922.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop_duplicates(inplace=True)
#                   Name  Age Marital Status    Education Level  \
# 0     Christine Barker   31        Married  Bachelor's Degree
# 1     Jacqueline Lewis   55        Married        High School
# 2       Shannon Church   78        Widowed    Master's Degree
# 3       Charles Jordan   58       Divorced    Master's Degree
# 4         Michael Rich   18         Single        High School
# ...                ...  ...            ...                ...
# 3763     Jessica Young   60        Widowed  Bachelor's Degree
# 3764   Bryan Gutierrez   51       Divorced  Bachelor's Degree
# 3765   Timothy Jackson   41        Married  Bachelor's Degree
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df['Marital Status'].unique()
# Out:
# array(['Married', 'Widowed', 'Divorced', 'Single'], dtype=object)

# %%
mar_dict = {'Married':1, 'Widowed':2,'Single':3,'Divorced':4}
df["Marital Status"]= df['Marital Status'].map(mar_dict)
# Out:
# C:\Users\yasha\AppData\Local\Temp\ipykernel_12700\576459789.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Marital Status"]= df['Marital Status'].map(mar_dict)

# %%
df
# Out:
#                   Name  Age  Marital Status    Education Level  \
# 0     Christine Barker   31               1  Bachelor's Degree
# 1     Jacqueline Lewis   55               1        High School
# 2       Shannon Church   78               2    Master's Degree
# 3       Charles Jordan   58               4    Master's Degree
# 4         Michael Rich   18               3        High School
# ...                ...  ...             ...                ...
# 3763     Jessica Young   60               2  Bachelor's Degree
# 3764   Bryan Gutierrez   51               4  Bachelor's Degree
# 3765   Timothy Jackson   41               1  Bachelor's Degree
# 3766      Jose Johnson   53               1        High School
# 3767     Eugene Thomas   54               1    Master's Degree
#
#       Number of Children Smoking Status Physical Activity Level  \
# 0                      2     Non-smoker                  Active
# 1                      1     Non-smoker               Sedentary
# ...

# %%
df['Education Level'].unique()
# Out:
# array(["Bachelor's Degree", 'High School', "Master's Degree",
#        'Associate Degree', 'PhD'], dtype=object)

# %%
edu_dict = mar_dict = {"Bachelor's Degree":1, 'High School':2,"Master's Degree":3,'Associate Degree':4,'PhD':5}
df['Education Level']= df['Education Level'].map(edu_dict)
# Out:
# C:\Users\yasha\AppData\Local\Temp\ipykernel_12700\882505861.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Education Level']= df['Education Level'].map(edu_dict)

# %%
df
# Out:
#                   Name  Age  Marital Status  Education Level  \
# 0     Christine Barker   31               1                1
# 1     Jacqueline Lewis   55               1                2
# 2       Shannon Church   78               2                3
# 3       Charles Jordan   58               4                3
# 4         Michael Rich   18               3                2
# ...                ...  ...             ...              ...
# 3763     Jessica Young   60               2                1
# 3764   Bryan Gutierrez   51               4                1
# 3765   Timothy Jackson   41               1                1
# 3766      Jose Johnson   53               1                2
# 3767     Eugene Thomas   54               1                3
#
#       Number of Children Smoking Status Physical Activity Level  \
# 0                      2     Non-smoker                  Active
# 1                      1     Non-smoker               Sedentary
# ...

# %%
df['Smoking Status'].unique()
# Out:
# array(['Non-smoker', 'Former', 'Current'], dtype=object)

# %%
smo_dict = mar_dict = {"Non-smoker":1, 'Former':2,"Current":3}
df['Smoking Status']= df['Smoking Status'].map(smo_dict)
# Out:
# C:\Users\yasha\AppData\Local\Temp\ipykernel_12700\3387852425.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Smoking Status']= df['Smoking Status'].map(smo_dict)

# %%
df
# Out:
#                   Name  Age  Marital Status  Education Level  \
# 0     Christine Barker   31               1                1
# 1     Jacqueline Lewis   55               1                2
# 2       Shannon Church   78               2                3
# 3       Charles Jordan   58               4                3
# 4         Michael Rich   18               3                2
# ...                ...  ...             ...              ...
# 3763     Jessica Young   60               2                1
# 3764   Bryan Gutierrez   51               4                1
# 3765   Timothy Jackson   41               1                1
# 3766      Jose Johnson   53               1                2
# 3767     Eugene Thomas   54               1                3
#
#       Number of Children  Smoking Status Physical Activity Level  \
# 0                      2               1                  Active
# 1                      1               1               Sedentary
# ...

# %%
df['Physical Activity Level'].unique()
# Out:
# array(['Active', 'Sedentary', 'Moderate'], dtype=object)

# %%
phy_dict = mar_dict = {'Active':1, 'Sedentary':2, 'Moderate':3}
df['Physical Activity Level']= df['Physical Activity Level'].map(phy_dict)
# Out:
# C:\Users\yasha\AppData\Local\Temp\ipykernel_12700\1227121307.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Physical Activity Level']= df['Physical Activity Level'].map(phy_dict)

# %%
df
# Out:
#                   Name  Age  Marital Status  Education Level  \
# 0     Christine Barker   31               1                1
# 1     Jacqueline Lewis   55               1                2
# 2       Shannon Church   78               2                3
# 3       Charles Jordan   58               4                3
# 4         Michael Rich   18               3                2
# ...                ...  ...             ...              ...
# 3763     Jessica Young   60               2                1
# 3764   Bryan Gutierrez   51               4                1
# 3765   Timothy Jackson   41               1                1
# 3766      Jose Johnson   53               1                2
# 3767     Eugene Thomas   54               1                3
#
#       Number of Children  Smoking Status  Physical Activity Level  \
# 0                      2               1                        1
# 1                      1               1                        2
# ...

# %%
df['Employment Status'].unique()
# Out:
# array(['Unemployed', 'Employed'], dtype=object)

# %%
emp_dict = mar_dict = {'Unemployed':1, 'Employed':2}
df['Employment Status']= df['Employment Status'].map(emp_dict)
# Out:
# C:\Users\yasha\AppData\Local\Temp\ipykernel_12700\2458744114.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Employment Status']= df['Employment Status'].map(emp_dict)

# %%
df
# Out:
#                   Name  Age  Marital Status  Education Level  \
# 0     Christine Barker   31               1                1
# 1     Jacqueline Lewis   55               1                2
# 2       Shannon Church   78               2                3
# 3       Charles Jordan   58               4                3
# 4         Michael Rich   18               3                2
# ...                ...  ...             ...              ...
# 3763     Jessica Young   60               2                1
# 3764   Bryan Gutierrez   51               4                1
# 3765   Timothy Jackson   41               1                1
# 3766      Jose Johnson   53               1                2
# 3767     Eugene Thomas   54               1                3
#
#       Number of Children  Smoking Status  Physical Activity Level  \
# 0                      2               1                        1
# 1                      1               1                        2
# ...

# %%
df["Alcohol Consumption"].unique()
# Out:
# array(['Moderate', 'High', 'Low'], dtype=object)

# %%
alc_dict = mar_dict = {'Moderate':1, 'High':2, 'Low':3}
df['Alcohol Consumption']= df['Alcohol Consumption'].map(alc_dict)
# Out:
# C:\Users\yasha\AppData\Local\Temp\ipykernel_12700\3152131106.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Alcohol Consumption']= df['Alcohol Consumption'].map(alc_dict)

# %%
df['Sleep Patterns'].unique()
# Out:
# array(['Fair', 'Good', 'Poor'], dtype=object)

# %%
sle_dict = mar_dict = {'Moderate':1, 'Unhealthy':2, 'Healthy':3}
df["Sleep Patterns"]= df['Sleep Patterns'].map(sle_dict)
# Out:
# C:\Users\yasha\AppData\Local\Temp\ipykernel_12700\3231122081.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Sleep Patterns"]= df['Sleep Patterns'].map(sle_dict)

# %%
df
# Out:
#                   Name  Age  Marital Status  Education Level  \
# 0     Christine Barker   31               1                1
# 1     Jacqueline Lewis   55               1                2
# 2       Shannon Church   78               2                3
# 3       Charles Jordan   58               4                3
# 4         Michael Rich   18               3                2
# ...                ...  ...             ...              ...
# 3763     Jessica Young   60               2                1
# 3764   Bryan Gutierrez   51               4                1
# 3765   Timothy Jackson   41               1                1
# 3766      Jose Johnson   53               1                2
# 3767     Eugene Thomas   54               1                3
#
#       Number of Children  Smoking Status  Physical Activity Level  \
# 0                      2               1                        1
# 1                      1               1                        2
# ...

# %%
df['History of Mental Illness'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
Hmi_dict = mar_dict = {'Yes':1, 'No':2}
df["History of Mental Illness"]= df['History of Mental Illness'].map(Hmi_dict)
# Out:
# C:\Users\yasha\AppData\Local\Temp\ipykernel_12700\3407612371.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["History of Mental Illness"]= df['History of Mental Illness'].map(Hmi_dict)

# %%
df['History of Substance Abuse'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
Hsa_dict = mar_dict = {'Yes':1, 'No':2}
df["History of Substance Abuse"]= df['History of Substance Abuse'].map(Hsa_dict)
# Out:
# C:\Users\yasha\AppData\Local\Temp\ipykernel_12700\1961773923.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["History of Substance Abuse"]= df['History of Substance Abuse'].map(Hsa_dict)

# %%
df['Family History of Depression'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
fhd_dict = mar_dict = {'Yes':1, 'No':2}
df["Family History of Depression"]= df['Family History of Depression'].map(fhd_dict)
# Out:
# C:\Users\yasha\AppData\Local\Temp\ipykernel_12700\3501149540.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Family History of Depression"]= df['Family History of Depression'].map(fhd_dict)

# %%
df['Chronic Medical Conditions'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
cmc_dict = mar_dict = {'Yes':1, 'No':2}
df["Chronic Medical Conditions"]= df['Chronic Medical Conditions'].map(cmc_dict)
# Out:
# C:\Users\yasha\AppData\Local\Temp\ipykernel_12700\1581978083.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Chronic Medical Conditions"]= df['Chronic Medical Conditions'].map(cmc_dict)

# %%
df
# Out:
#                   Name  Age  Marital Status  Education Level  \
# 0     Christine Barker   31               1                1
# 1     Jacqueline Lewis   55               1                2
# 2       Shannon Church   78               2                3
# 3       Charles Jordan   58               4                3
# 4         Michael Rich   18               3                2
# ...                ...  ...             ...              ...
# 3763     Jessica Young   60               2                1
# 3764   Bryan Gutierrez   51               4                1
# 3765   Timothy Jackson   41               1                1
# 3766      Jose Johnson   53               1                2
# 3767     Eugene Thomas   54               1                3
#
#       Number of Children  Smoking Status  Physical Activity Level  \
# 0                      2               1                        1
# 1                      1               1                        2
# ...

# %%
df=df.drop(columns=['Sleep Patterns'])
df
# Out:
#                   Name  Age  Marital Status  Education Level  \
# 0     Christine Barker   31               1                1
# 1     Jacqueline Lewis   55               1                2
# 2       Shannon Church   78               2                3
# 3       Charles Jordan   58               4                3
# 4         Michael Rich   18               3                2
# ...                ...  ...             ...              ...
# 3763     Jessica Young   60               2                1
# 3764   Bryan Gutierrez   51               4                1
# 3765   Timothy Jackson   41               1                1
# 3766      Jose Johnson   53               1                2
# 3767     Eugene Thomas   54               1                3
#
#       Number of Children  Smoking Status  Physical Activity Level  \
# 0                      2               1                        1
# 1                      1               1                        2
# ...

# %%
df=df.drop(columns=['Dietary Habits'])
df
# Out:
#                   Name  Age  Marital Status  Education Level  \
# 0     Christine Barker   31               1                1
# 1     Jacqueline Lewis   55               1                2
# 2       Shannon Church   78               2                3
# 3       Charles Jordan   58               4                3
# 4         Michael Rich   18               3                2
# ...                ...  ...             ...              ...
# 3763     Jessica Young   60               2                1
# 3764   Bryan Gutierrez   51               4                1
# 3765   Timothy Jackson   41               1                1
# 3766      Jose Johnson   53               1                2
# 3767     Eugene Thomas   54               1                3
#
#       Number of Children  Smoking Status  Physical Activity Level  \
# 0                      2               1                        1
# 1                      1               1                        2
# ...

# %%
df = df.drop(columns=['Name'])
df
# Out:
#       Age  Marital Status  Education Level  Number of Children  \
# 0      31               1                1                   2
# 1      55               1                2                   1
# 2      78               2                3                   1
# 3      58               4                3                   3
# 4      18               3                2                   0
# ...   ...             ...              ...                 ...
# 3763   60               2                1                   3
# 3764   51               4                1                   3
# 3765   41               1                1                   0
# 3766   53               1                2                   1
# 3767   54               1                3                   2
#
#       Smoking Status  Physical Activity Level  Employment Status     Income  \
# 0                  1                        1                  1   26265.67
# ...

# %%
df.to_csv('clean_survey_depression.csv')

# %%
df
# Out:
#       Age  Marital Status  Education Level  Number of Children  \
# 0      31               1                1                   2
# 1      55               1                2                   1
# 2      78               2                3                   1
# 3      58               4                3                   3
# 4      18               3                2                   0
# ...   ...             ...              ...                 ...
# 3763   60               2                1                   3
# 3764   51               4                1                   3
# 3765   41               1                1                   0
# 3766   53               1                2                   1
# 3767   54               1                3                   2
#
#       Smoking Status  Physical Activity Level  Employment Status     Income  \
# 0                  1                        1                  1   26265.67
# ...

# %%
x = df.drop('History of Mental Illness', axis=1)
y = df['History of Mental Illness']

# %%
x
# Out:
#       Age  Marital Status  Education Level  Number of Children  \
# 0      31               1                1                   2
# 1      55               1                2                   1
# 2      78               2                3                   1
# 3      58               4                3                   3
# 4      18               3                2                   0
# ...   ...             ...              ...                 ...
# 3763   60               2                1                   3
# 3764   51               4                1                   3
# 3765   41               1                1                   0
# 3766   53               1                2                   1
# 3767   54               1                3                   2
#
#       Smoking Status  Physical Activity Level  Employment Status     Income  \
# 0                  1                        1                  1   26265.67
# ...

# %%
y
# Out:
# 0       1
# 1       1
# 2       2
# 3       2
# 4       1
#        ..
# 3763    2
# 3764    2
# 3765    2
# 3766    1
# 3767    2
# Name: History of Mental Illness, Length: 3768, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
x_train
# Out:
#       Age  Marital Status  Education Level  Number of Children  \
# 1352   54               1                1                   1
# 2290   30               1                2                   0
# 485    61               1                2                   3
# 2183   37               3                4                   0
# 3317   24               1                2                   2
# ...   ...             ...              ...                 ...
# 1130   19               3                2                   0
# 1294   69               1                3                   2
# 860    47               1                3                   2
# 3507   59               1                4                   3
# 3174   32               1                4                   3
#
#       Smoking Status  Physical Activity Level  Employment Status     Income  \
# 1352               1                        2                  1   25003.97
# ...

# %%
x_train
# Out:
#       Age  Marital Status  Education Level  Number of Children  \
# 1352   54               1                1                   1
# 2290   30               1                2                   0
# 485    61               1                2                   3
# 2183   37               3                4                   0
# 3317   24               1                2                   2
# ...   ...             ...              ...                 ...
# 1130   19               3                2                   0
# 1294   69               1                3                   2
# 860    47               1                3                   2
# 3507   59               1                4                   3
# 3174   32               1                4                   3
#
#       Smoking Status  Physical Activity Level  Employment Status     Income  \
# 1352               1                        2                  1   25003.97
# ...

# %%
y_train
# Out:
# 1352    1
# 2290    2
# 485     2
# 2183    2
# 3317    2
#        ..
# 1130    2
# 1294    2
# 860     2
# 3507    2
# 3174    1
# Name: History of Mental Illness, Length: 3014, dtype: int64

# %%
y_test
# Out:
# 3538    2
# 2991    2
# 220     2
# 2970    2
# 1953    2
#        ..
# 752     2
# 2599    2
# 1659    2
# 612     2
# 1173    2
# Name: History of Mental Illness, Length: 754, dtype: int64

# %%
x_test.shape,y_test.shape,x_train.shape,y_train.shape
# Out:
# ((754, 12), (754,), (3014, 12), (3014,))

# %%
from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier()

# %%
from sklearn.svm import SVC
clf = SVC()

# %%
import joblib

# %%
joblib.dump(clf, 'model.joblib')
# Out:
# ['model.joblib']

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
y_pred = clf.predict(x_test)

# %%
clf = RandomForestClassifier(random_state=42)
clf.fit(x_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
y_pred = clf.predict(x_test)

# %%
accuracy_score(y_test, y_pred)
#accuracy
# Out:
# 0.7320954907161804

# %%
classification_report(y_test, y_pred)
# Out:
# c:\Users\yasha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1706: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\yasha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1706: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\yasha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1706: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
# ...

# %%
print("Accuracy:", accuracy_score(y_test, y_pred))
print("\nClassification Report:\n", classification_report(y_test, y_pred))
print("\nConfusion Matrix:\n", confusion_matrix(y_test, y_pred))
# Out:
# Accuracy: 0.7320954907161804
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            1       0.00      0.00      0.00       202
#            2       0.73      1.00      0.85       552
#
#     accuracy                           0.73       754
#    macro avg       0.37      0.50      0.42       754
# weighted avg       0.54      0.73      0.62       754
#
#
# Confusion Matrix:
#  [[  0 202]
#  [  0 552]]
# c:\Users\yasha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1706: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# ...

# %%
from sklearn.linear_model import LogisticRegression
clf = LogisticRegression(max_iter=1000, random_state=42)
clf.fit(x_train, y_train)
y_pred = clf.predict(x_test)
print("Accuracy:", accuracy_score(y_test, y_pred))
print("\nClassification Report:\n", classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.7307692307692307
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            1       0.33      0.00      0.01       202
#            2       0.73      1.00      0.84       552
#
#     accuracy                           0.73       754
#    macro avg       0.53      0.50      0.43       754
# weighted avg       0.63      0.73      0.62       754

# %%
from sklearn.svm import SVC
clf = SVC()
clf.fit(x_train, y_train)
y_pred = clf.predict(x_test)
print("Accuracy:", accuracy_score(y_test, y_pred))
print("\nClassification Report:\n", classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.7320954907161804
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            1       0.00      0.00      0.00       202
#            2       0.73      1.00      0.85       552
#
#     accuracy                           0.73       754
#    macro avg       0.37      0.50      0.42       754
# weighted avg       0.54      0.73      0.62       754
# c:\Users\yasha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1706: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# ...
