# %%
import pandas as pd

# %%
df=pd.read_csv("LaptopPrice.csv")

# %%
df
# Out:
#       brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0      ASUS           Intel        Core i3            10th   4 GB     DDR4
# 1    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 2    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 3      ASUS           Intel        Core i5            10th   8 GB     DDR4
# 4      ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# ..      ...             ...            ...             ...    ...      ...
# 818    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 819    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 820    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 821    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 822  Lenovo             AMD        Ryzen 5            10th   8 GB     DDR4
#
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(21)

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isnull()
# Out:
#      brand  processor_brand  processor_name  processor_gnrtn  ram_gb  \
# 0    False            False           False            False   False
# 1    False            False           False            False   False
# 2    False            False           False            False   False
# 3    False            False           False            False   False
# 4    False            False           False            False   False
# ..     ...              ...             ...              ...     ...
# 818  False            False           False            False   False
# 819  False            False           False            False   False
# 820  False            False           False            False   False
# 821  False            False           False            False   False
# 822  False            False           False            False   False
#
#      ram_type    ssd    hdd     os  os_bit  graphic_card_gb  weight  warranty  \
# ...

# %%
df.dropna()
# Out:
#       brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0      ASUS           Intel        Core i3            10th   4 GB     DDR4
# 1    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 2    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 3      ASUS           Intel        Core i5            10th   8 GB     DDR4
# 4      ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# ..      ...             ...            ...             ...    ...      ...
# 818    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 819    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 820    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 821    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 822  Lenovo             AMD        Ryzen 5            10th   8 GB     DDR4
#
# ...

# %%
df.drop(['os','os_bit','weight','msoffice','rating','Number of Ratings','Number of Reviews'],axis=1,inplace=True)

# %%
df
# Out:
#       brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0      ASUS           Intel        Core i3            10th   4 GB     DDR4
# 1    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 2    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 3      ASUS           Intel        Core i5            10th   8 GB     DDR4
# 4      ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# ..      ...             ...            ...             ...    ...      ...
# 818    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 819    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 820    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 821    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 822  Lenovo             AMD        Ryzen 5            10th   8 GB     DDR4
#
# ...

# %%
df['brand'].unique()
# Out:
# array(['ASUS', 'Lenovo', 'acer', 'Avita', 'HP', 'DELL', 'MSI', 'APPLE'],
#       dtype=object)

# %%
brand_dict={'ASUS':1, 'Lenovo':2, 'acer':3, 'Avita':4, 'HP':5, 'DELL':6, 'MSI':7, 'APPLE':8}

# %%
df['brand']=df['brand'].map(brand_dict)

# %%
df
# Out:
#      brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0        1           Intel        Core i3            10th   4 GB     DDR4
# 1        2           Intel        Core i3            10th   4 GB     DDR4
# 2        2           Intel        Core i3            10th   4 GB     DDR4
# 3        1           Intel        Core i5            10th   8 GB     DDR4
# 4        1           Intel   Celeron Dual   Not Available   4 GB     DDR4
# ..     ...             ...            ...             ...    ...      ...
# 818      1             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 819      1             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 820      1             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 821      1             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 822      2             AMD        Ryzen 5            10th   8 GB     DDR4
#
#          ssd      hdd graphic_card_gb     warranty Touchscreen   Price
# ...

# %%
df['processor_brand'].unique()
# Out:
# array(['Intel', 'AMD', 'M1'], dtype=object)

# %%
proc_brand_dict={'Intel':1, 'AMD':2, 'M1':3}

# %%
df['processor_brand']=df['processor_brand'].map(proc_brand_dict)

# %%
df
# Out:
#      brand  processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0        1                1        Core i3            10th   4 GB     DDR4
# 1        2                1        Core i3            10th   4 GB     DDR4
# 2        2                1        Core i3            10th   4 GB     DDR4
# 3        1                1        Core i5            10th   8 GB     DDR4
# 4        1                1   Celeron Dual   Not Available   4 GB     DDR4
# ..     ...              ...            ...             ...    ...      ...
# 818      1                2        Ryzen 9   Not Available   4 GB     DDR4
# 819      1                2        Ryzen 9   Not Available   4 GB     DDR4
# 820      1                2        Ryzen 9   Not Available   4 GB     DDR4
# 821      1                2        Ryzen 9   Not Available   4 GB     DDR4
# 822      2                2        Ryzen 5            10th   8 GB     DDR4
#
# ...

# %%
df['processor_name'].unique()
# Out:
# array(['Core i3', 'Core i5', 'Celeron Dual', 'Ryzen 5', 'Core i7',
#        'Core i9', 'M1', 'Pentium Quad', 'Ryzen 3', 'Ryzen 7', 'Ryzen 9'],
#       dtype=object)

# %%
proc_name_dict={'Core i3':1, 'Core i5':2, 'Celeron Dual':3, 'Ryzen 5':4, 'Core i7':5,
       'Core i9':6, 'M1':7, 'Pentium Quad':8, 'Ryzen 3':9, 'Ryzen 7':10, 'Ryzen 9':11}

# %%
df['processor_name']=df['processor_name'].map(proc_name_dict)

# %%
df
# Out:
#      brand  processor_brand  processor_name processor_gnrtn ram_gb ram_type  \
# 0        1                1               1            10th   4 GB     DDR4
# 1        2                1               1            10th   4 GB     DDR4
# 2        2                1               1            10th   4 GB     DDR4
# 3        1                1               2            10th   8 GB     DDR4
# 4        1                1               3   Not Available   4 GB     DDR4
# ..     ...              ...             ...             ...    ...      ...
# 818      1                2              11   Not Available   4 GB     DDR4
# 819      1                2              11   Not Available   4 GB     DDR4
# 820      1                2              11   Not Available   4 GB     DDR4
# 821      1                2              11   Not Available   4 GB     DDR4
# 822      2                2               4            10th   8 GB     DDR4
#
# ...

# %%
df['processor_gnrtn'].unique()
# Out:
# array(['10th', 'Not Available', '11th', '7th', '8th', '9th', '4th',
#        '12th'], dtype=object)

# %%
proc_gen_dict={'10th':1, 'Not Available':2, '11th':3, '7th':4, '8th':5, '9th':6, '4th':7,
       '12th':8}

# %%
df['processor_gnrtn']=df['processor_gnrtn'].map(proc_gen_dict)

# %%
df
# Out:
#      brand  processor_brand  processor_name  processor_gnrtn ram_gb ram_type  \
# 0        1                1               1                1   4 GB     DDR4
# 1        2                1               1                1   4 GB     DDR4
# 2        2                1               1                1   4 GB     DDR4
# 3        1                1               2                1   8 GB     DDR4
# 4        1                1               3                2   4 GB     DDR4
# ..     ...              ...             ...              ...    ...      ...
# 818      1                2              11                2   4 GB     DDR4
# 819      1                2              11                2   4 GB     DDR4
# 820      1                2              11                2   4 GB     DDR4
# 821      1                2              11                2   4 GB     DDR4
# 822      2                2               4                1   8 GB     DDR4
#
# ...

# %%
df.dtypes
# Out:
# brand               int64
# processor_brand     int64
# processor_name      int64
# processor_gnrtn     int64
# ram_gb             object
# ram_type           object
# ssd                object
# hdd                object
# graphic_card_gb    object
# warranty           object
# Touchscreen        object
# Price               int64
# dtype: object

# %%
df['ram_gb'].unique()
# Out:
# array(['4 GB', '8 GB', '16 GB', '32 GB'], dtype=object)

# %%
ram_gb_dict={'4 GB':4, '8 GB':8, '16 GB':16, '32 GB':32}

# %%
df['ram_gb']=df['ram_gb'].map(ram_gb_dict)

# %%
df
# Out:
#      brand  processor_brand  processor_name  processor_gnrtn  ram_gb ram_type  \
# 0        1                1               1                1       4     DDR4
# 1        2                1               1                1       4     DDR4
# 2        2                1               1                1       4     DDR4
# 3        1                1               2                1       8     DDR4
# 4        1                1               3                2       4     DDR4
# ..     ...              ...             ...              ...     ...      ...
# 818      1                2              11                2       4     DDR4
# 819      1                2              11                2       4     DDR4
# 820      1                2              11                2       4     DDR4
# 821      1                2              11                2       4     DDR4
# 822      2                2               4                1       8     DDR4
#
# ...

# %%
df['ram_type'].unique()
# Out:
# array(['DDR4', 'LPDDR4', 'LPDDR4X', 'DDR5', 'DDR3', 'LPDDR3'],
#       dtype=object)

# %%
ram_type_dict={'DDR4':1, 'LPDDR4':2, 'LPDDR4X':3, 'DDR5':4, 'DDR3':5, 'LPDDR3':6}

# %%
df['ram_type']=df['ram_type'].map(ram_type_dict)

# %%
df
# Out:
#      brand  processor_brand  processor_name  processor_gnrtn  ram_gb  \
# 0        1                1               1                1       4
# 1        2                1               1                1       4
# 2        2                1               1                1       4
# 3        1                1               2                1       8
# 4        1                1               3                2       4
# ..     ...              ...             ...              ...     ...
# 818      1                2              11                2       4
# 819      1                2              11                2       4
# 820      1                2              11                2       4
# 821      1                2              11                2       4
# 822      2                2               4                1       8
#
#      ram_type      ssd      hdd graphic_card_gb     warranty Touchscreen  \
# ...

# %%
df['ssd'].unique()
# Out:
# array(['0 GB', '512 GB', '256 GB', '128 GB', '1024 GB', '2048 GB',
#        '3072 GB'], dtype=object)

# %%
ssd_dict={'0 GB':0, '512 GB':512,'256 GB':256, '128 GB':128, '1024 GB':1024, '2048 GB':2048,
       '3072 GB':3072}

# %%
df['ssd']=df['ssd'].map(ssd_dict)

# %%
df
# Out:
#      brand  processor_brand  processor_name  processor_gnrtn  ram_gb  \
# 0        1                1               1                1       4
# 1        2                1               1                1       4
# 2        2                1               1                1       4
# 3        1                1               2                1       8
# 4        1                1               3                2       4
# ..     ...              ...             ...              ...     ...
# 818      1                2              11                2       4
# 819      1                2              11                2       4
# 820      1                2              11                2       4
# 821      1                2              11                2       4
# 822      2                2               4                1       8
#
#      ram_type   ssd      hdd graphic_card_gb     warranty Touchscreen   Price
# ...

# %%
df['hdd'].unique()
# Out:
# array(['1024 GB', '0 GB', '512 GB', '2048 GB'], dtype=object)

# %%
hdd_dict={'1024 GB':1024, '0 GB':0, '512 GB':512, '2048 GB':2048}

# %%
df['hdd']=df['hdd'].map(hdd_dict)

# %%
df
# Out:
#      brand  processor_brand  processor_name  processor_gnrtn  ram_gb  \
# 0        1                1               1                1       4
# 1        2                1               1                1       4
# 2        2                1               1                1       4
# 3        1                1               2                1       8
# 4        1                1               3                2       4
# ..     ...              ...             ...              ...     ...
# 818      1                2              11                2       4
# 819      1                2              11                2       4
# 820      1                2              11                2       4
# 821      1                2              11                2       4
# 822      2                2               4                1       8
#
#      ram_type   ssd   hdd graphic_card_gb     warranty Touchscreen   Price
# ...

# %%
df['graphic_card_gb'].unique()
# Out:
# array(['0 GB', '2 GB', '4 GB', '6 GB', '8 GB'], dtype=object)

# %%
graphic_card_dict={'0 GB':0, '2 GB':2, '4 GB':4, '6 GB':6, '8 GB':8}

# %%
df['graphic_card_gb']=df['graphic_card_gb'].map(graphic_card_dict)

# %%
df
# Out:
#      brand  processor_brand  processor_name  processor_gnrtn  ram_gb  \
# 0        1                1               1                1       4
# 1        2                1               1                1       4
# 2        2                1               1                1       4
# 3        1                1               2                1       8
# 4        1                1               3                2       4
# ..     ...              ...             ...              ...     ...
# 818      1                2              11                2       4
# 819      1                2              11                2       4
# 820      1                2              11                2       4
# 821      1                2              11                2       4
# 822      2                2               4                1       8
#
#      ram_type   ssd   hdd  graphic_card_gb     warranty Touchscreen   Price
# ...

# %%
df['warranty'].unique()
# Out:
# array(['No warranty', '1 year', '2 years', '3 years'], dtype=object)

# %%
warranty_dict={'No warranty':1, '1 year':2, '2 years':3, '3 years':4}

# %%
df['warranty']=df['warranty'].map(warranty_dict)

# %%
df
# Out:
#      brand  processor_brand  processor_name  processor_gnrtn  ram_gb  \
# 0        1                1               1                1       4
# 1        2                1               1                1       4
# 2        2                1               1                1       4
# 3        1                1               2                1       8
# 4        1                1               3                2       4
# ..     ...              ...             ...              ...     ...
# 818      1                2              11                2       4
# 819      1                2              11                2       4
# 820      1                2              11                2       4
# 821      1                2              11                2       4
# 822      2                2               4                1       8
#
#      ram_type   ssd   hdd  graphic_card_gb  warranty Touchscreen   Price
# ...

# %%
df['Touchscreen'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
touchscreen_dict={'No':1, 'Yes':2}

# %%
df['Touchscreen']=df['Touchscreen'].map(touchscreen_dict)

# %%
df
# Out:
#      brand  processor_brand  processor_name  processor_gnrtn  ram_gb  \
# 0        1                1               1                1       4
# 1        2                1               1                1       4
# 2        2                1               1                1       4
# 3        1                1               2                1       8
# 4        1                1               3                2       4
# ..     ...              ...             ...              ...     ...
# 818      1                2              11                2       4
# 819      1                2              11                2       4
# 820      1                2              11                2       4
# 821      1                2              11                2       4
# 822      2                2               4                1       8
#
#      ram_type   ssd   hdd  graphic_card_gb  warranty  Touchscreen   Price
# ...

# %%
df.to_csv('clean_lptp.csv')

# %%
x=df.drop('Price',axis=1)
y=df[['Price']]

# %%
x
# Out:
#      brand  processor_brand  processor_name  processor_gnrtn  ram_gb  \
# 0        1                1               1                1       4
# 1        2                1               1                1       4
# 2        2                1               1                1       4
# 3        1                1               2                1       8
# 4        1                1               3                2       4
# ..     ...              ...             ...              ...     ...
# 818      1                2              11                2       4
# 819      1                2              11                2       4
# 820      1                2              11                2       4
# 821      1                2              11                2       4
# 822      2                2               4                1       8
#
#      ram_type   ssd   hdd  graphic_card_gb  warranty  Touchscreen
# 0           1     0  1024                0         1            1
# ...

# %%
y
# Out:
#       Price
# 0     34649
# 1     38999
# 2     39999
# 3     69990
# 4     26990
# ..      ...
# 818  135990
# 819  144990
# 820  149990
# 821  142990
# 822   57490
#
# [802 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, random_state=42, test_size=0.2)

# %%
x_train
# Out:
#      brand  processor_brand  processor_name  processor_gnrtn  ram_gb  \
# 442      1                1               2                3       8
# 598      1                1               5                1      16
# 452      1                1               2                3       8
# 696      6                2               4                2       8
# 339      1                1               2                3       8
# ..     ...              ...             ...              ...     ...
# 73       2                1               1                1       4
# 108      6                1               1                3       8
# 275      2                1               2                1       8
# 445      1                1               2                3       8
# 104      1                1               1                3       8
#
#      ram_type  ssd   hdd  graphic_card_gb  warranty  Touchscreen
# 442         1  256  1024                0         2            1
# ...

# %%
x_test
# Out:
#      brand  processor_brand  processor_name  processor_gnrtn  ram_gb  \
# 196      3                1               2                2       8
# 299      1                1               2                3       8
# 171      6                1               1                1       8
# 537      5                1               5                1      16
# 551      7                1               5                3      16
# ..     ...              ...             ...              ...     ...
# 368      1                1               2                3       8
# 361      5                1               2                1       8
# 446      6                1               2                3       8
# 767      2                2              10                2       4
# 529      2                1               5                3      16
#
#      ram_type   ssd   hdd  graphic_card_gb  warranty  Touchscreen
# 196         4     0   512                4         1            1
# ...

# %%
y_train
# Out:
#       Price
# 442   50990
# 598  146490
# 452   60190
# 696   59490
# 339   99990
# ..      ...
# 73    41990
# 108   60790
# 275   57500
# 445   52990
# 104   44990
#
# [641 rows x 1 columns]

# %%
y_test
# Out:
#       Price
# 196   50990
# 299   72990
# 171   41490
# 537  144690
# 551  129990
# ..      ...
# 368  114990
# 361  126000
# 446   57990
# 767  106990
# 529  110999
#
# [161 rows x 1 columns]

# %%
x_test.shape,y_test.shape,x_train.shape,y_train.shape
# Out:
# ((161, 11), (161, 1), (641, 11), (641, 1))

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lr.score(x_test,y_test)
# Out:
# 0.5126275942844929

# %%
pred=lr.predict(x_test)

# %%
pred
# Out:
# array([[ 83644.0261531 ],
#        [ 73548.12274394],
#        [ 64293.63389928],
#        [153554.87865022],
#        [166395.54454022],
#        [151272.1471979 ],
#        [ 88358.42610495],
#        [ 95575.54766501],
#        [ 55432.41089828],
#        [ 83154.73545359],
#        [ 25034.14738201],
#        [ 46548.40633215],
#        [ 75577.81015065],
#        [ 92345.0537206 ],
#        [ 64286.94570361],
#        [ 82854.41158117],
#        [ 84287.39071307],
#        [ 63985.95821769],
#        [ 63093.22403857],
#        [162379.54238514],
#        [ 36132.47773946],
#        [ 27957.56940781],
#        [ 75358.43789849],
#        [ 47979.24110685],
#        [ 35618.38254811],
#        [ 39456.21376262],
#        [ 78696.59549018],
#        [158756.63464953],
#        [ 38563.47958351],
#        [ 26897.74578964],
#        [ 57810.10449726],
#        [ 53775.23200041],
#        [ 62820.97126157],
#        [ 57317.91255552],
#        [ 55216.57972919],
# ...

# %%
from sklearn.datasets import load_iris
x, y = load_iris(return_X_y=True)

# %%
from sklearn.svm import SVC
sv=SVC()
sv.fit(x,y)
# Out:
# SVC()

# %%
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier()
knn.fit(x,y)
knn.score(x,y)
# Out:
# 0.9666666666666667

# %%
from sklearn.tree import DecisionTreeRegressor,DecisionTreeClassifier
# dt=DecisionTreeRegressor(max_depth=3,random_state=42)
dt= DecisionTreeClassifier()
dt.fit(x_train,y_train)
# Out:
# c:\Users\yasha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\multiclass.py:213: UserWarning: The number of unique classes is greater than 50% of the number of samples.
#   y_type = type_of_target(y, input_name="y")
# DecisionTreeClassifier()

# %%
dt.score(x_test,y_test)
# Out:
# c:\Users\yasha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:98: UserWarning: The number of unique classes is greater than 50% of the number of samples.
#   type_true = type_of_target(y_true, input_name="y_true")
# c:\Users\yasha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:99: UserWarning: The number of unique classes is greater than 50% of the number of samples.
#   type_pred = type_of_target(y_pred, input_name="y_pred")
# 0.024844720496894408

# %%
import joblib
joblib.dump(dt,'model.joblib')
# Out:
# ['model.joblib']

# %%
model=joblib.load('model.joblib')

# %%
model.predict(x_test)
# Out:
# array([ 46990,  63990,  39490, 224990, 171990, 124990, 101990,  60990,
#         49490, 155411,  35990,  34990,  59990, 121990,  68500, 109990,
#         57500,  41990,  55490,  93955,  41790,  38940,  65990,  36000,
#         39490,  39990,  57500, 159990,  99500,  39998,  56990,  53190,
#         39990,  57490,  44990,  35990, 101990,  70990,  54238,  65990,
#         40200,  59990,  49970,  38680, 101990,  55990, 162990,  60990,
#         84500,  63990, 154990, 179990,  46990,  78000,  64190, 134990,
#         87990,  41250,  64190,  98990,  72400,  27990,  35990,  63990,
#         57990,  71990, 136990,  39990,  35990,  32955,  85990, 135990,
#        139990, 121990,  39990,  37890, 128990,  79990,  49490,  44990,
#         48990,  59999,  74590,  35990,  39490,  54990, 135300,  92000,
#         55990, 124990,  59990,  49990,  63990, 155411,  34990,  99999,
#        179990,  59990,  36000,  55999,  39490,  37990,  79990,  49890,
# ...

# %%
y_test
# Out:
#       Price
# 196   50990
# 299   72990
# 171   41490
# 537  144690
# 551  129990
# ..      ...
# 368  114990
# 361  126000
# 446   57990
# 767  106990
# 529  110999
#
# [161 rows x 1 columns]

# %%
from sklearn.ensemble import RandomForestClassifier,AdaBoostClassifier
rf= RandomForestClassifier()

# %%
from sklearn.naive_bayes import GaussianNB,MultinomialNB,BernoulliNB
from sklearn.datasets import load_breast_cancer
x,y=load_breast_cancer(return_X_y=True)
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

#cell
gnb=GaussianNB()
gnb.fit(x_train,y_train)
# Out:
# GaussianNB()
