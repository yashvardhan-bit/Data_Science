# %%
# %pip install matplotlib

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
x=np.array([1,2,3])

# %%
# plot
# scatter
# hist
# bar 
# boxplot
# pie

# %%
plt.plot(x)
plt.show()

# %%
x=np.array([1,2,3,4,5])
y=np.array([9,8,7,6,2])
plt.plot(x,y)
plt.show()

# %%
x=np.array([1,2,3,4,5])
y=np.array([9,8,7,6,2])
plt.plot(x,y,marker=".",)
plt.show()

# %%
x=np.array([1,2,3,4,5])
y=np.array([9,8,7,6,2])
# plot with dot marker and marker size 32
plt.plot(x, y, marker=".", markersize=32)# can also write ms
plt.show()

# %%
x=np.array([1,2,3,4,5])
y=np.array([9,8,7,6,2])
# plot with star marker, marker size 32, red face color, and green edge color
plt.plot(x, y, marker="*", ms=32, markerfacecolor="red", mec="green")
plt.show()

# %%
x_point=np.array([1,2,3,4,5])
y_point=np.array([9,7,8,5,6])
plt.plot(y_point,linestyle="dashed")
plt.show()

# %%
x_point=np.array([1,2,3,4,5])
y_point=np.array([9,7,8,5,6])
plt.plot(x_point,linestyle="dotted")
plt.show()

# %%
# Set up the title and axis labels for the plot
plt.title("graph", fontsize=22, fontweight="bold", color="pink")
plt.xlabel("x-axis")
plt.ylabel("y-axis")
# Show grid on the plot
plt.grid(True)

# Plot x_point with dotted line style
plt.plot(x_point, linestyle="dotted")
# Plot y_point with dotted line style
plt.plot(y_point, linestyle="dotted")

# Display the plot
plt.show()

# %%
#scatter plot
x=np.array([1,2,3,4,5])
y=np.array([2,4,5,3,1])
c=np.array(["red","green","blue","yellow","orange"])
size=np.array([10,20,30,40,50])
plt.scatter(x, y,alpha=0.7, c=c, s=size)
plt.show()

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
sizes = np.array([20,50,100,200,500,1000,60,90,10,300,600,800,75])
c = np.array(['red', 'green', 'blue', 'yellow', 'cyan', 'magenta', 'black', 'orange', 'red', 'green', 'blue', 'yellow', 'cyan'])
plt.scatter(x, y, alpha=0.5, s=sizes, c=c,cmap='viridis')  # cmap since c is an array of color names
# plt.colorbar()
plt.show()
# Out:
# C:\Users\yasha\AppData\Local\Temp\ipykernel_9352\1544288794.py:5: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(x, y, alpha=0.5, s=sizes, c=c,cmap='viridis')  # cmap since c is an array of color names

# %% [markdown]
# BARPLOT

# %%
x_point=np.array([1,2,3,4,5])
y_point=np.array([2,4,6,2,10])
plt.bar(x_point,y_point)
plt.show()

# %%
x=np.array([1,2,3,4,5])
y=np.array([2,4,6,2,10])
plt.barh(x,y)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
x=np.array([1,2,3,4,5])
y=np.array([2,4,6,2,10])
plt.bar(x,y,color="green")
plt.show()

# %%
x = np.array([2, 2, 3, 4, 5])
y = np.array(['A', 'B', 'C', 'D', 'E'])
color = np.array(['red', 'green', 'blue', 'grey', 'purple'])
plt.bar(x, y, color=color, width=0.3)
plt.show()

# %%
# plt.figure
# DIY

# %% [markdown]
# HISTPLOT

# %%
x=np.random.normal(170,10,250)
x
# Out:
# array([166.48185994, 153.02592952, 163.17059484, 161.34056631,
#        167.28273488, 152.47327524, 161.00051456, 176.64372814,
#        173.21062276, 180.36469148, 182.23732955, 164.21507833,
#        170.08839646, 169.41406316, 168.13909485, 174.41479525,
#        162.59003879, 183.43956032, 167.08130648, 167.23847448,
#        167.74219806, 177.04625504, 174.77171226, 166.93665093,
#        165.1578124 , 159.01230168, 164.88849906, 186.604431  ,
#        181.93551796, 175.03547293, 164.36489655, 179.16171116,
#        180.92886422, 173.54276564, 164.60499143, 168.08988781,
#        164.72324176, 166.51826889, 158.48045561, 159.26758009,
#        170.45493924, 163.50949279, 160.1877876 , 165.68779581,
#        166.34127722, 175.30329406, 165.31446364, 183.42109003,
#        173.68434878, 169.42570299, 165.2487559 , 171.93614701,
#        175.4284614 , 180.23099921, 177.84872592, 154.62348444,
#        187.42106809, 168.92877368, 169.75109676, 171.65340022,
#        172.87408463, 158.61906992, 155.99605995, 163.79362079,
#        171.58333413, 168.21818879, 170.01271465, 166.88006336,
#        173.20181441, 164.51874154, 169.4271286 , 166.01044155,
#        190.98629376, 188.65236556, 178.39346977, 162.81450922,
#        161.90023736, 169.61112513, 185.09727224, 161.67501863,
#        160.51787746, 168.53212606, 162.96569723, 173.31278426,
#        195.62257482, 153.195416  , 152.99151804, 164.87377012,
#        158.13169575, 154.78793555, 177.48281234, 170.7494229 ,
#        172.62558059, 153.20841523, 166.84775389, 175.85520768,
#        165.53765873, 172.17469543, 177.19309304, 155.24541798,
#        172.81137751, 171.95533531, 178.95115542, 187.07507383,
#        166.8887754 , 165.63415581, 142.37641971, 180.9832459 ,
#        159.77539814, 166.68905151, 176.53856998, 176.43589874,
#        181.11017434, 184.74503355, 174.60653672, 164.18891571,
#        165.51601801, 151.70657196, 163.35304461, 166.39442085,
#        162.40611198, 140.72885669, 176.07628216, 177.49633263,
#        159.39448894, 187.2223877 , 177.60941399, 163.39948584,
#        174.32588297, 169.06459822, 162.15730249, 164.61620851,
#        159.783153  , 169.92395296, 175.32608066, 151.02156234,
#        161.32712258, 176.24731832, 177.3725719 , 166.65512348,
#        169.95966167, 172.62232769, 176.93366093, 173.98834121,
#        169.82264814, 177.44884806, 179.87302872, 158.43942665,
#        179.62521454, 178.28050444, 160.75813353, 189.43735148,
#        182.45422185, 172.48719835, 173.89236324, 172.52568648,
#        183.41429462, 164.00742828, 166.69382839, 185.9406651 ,
#        166.23318042, 175.99177204, 151.88658156, 159.83084181,
#        158.16794183, 156.04383219, 178.64185955, 182.98499778,
#        186.35990312, 158.68707989, 178.05098474, 191.60934029,
#        171.74124356, 167.1571994 , 172.7846652 , 159.32522448,
#        168.17563824, 166.65436149, 164.52485379, 178.19051825,
#        181.19437417, 177.88790465, 178.54785209, 167.77593321,
#        168.21978253, 161.68551635, 178.8405701 , 163.46599403,
#        171.43665516, 169.05567159, 172.35089063, 175.83842159,
#        176.88375948, 167.83249819, 166.00755654, 169.5046978 ,
#        162.47855972, 165.89742134, 179.47868072, 169.37730543,
#        163.9990629 , 164.21061944, 177.46876559, 165.84204967,
#        181.34025981, 161.47718523, 169.08938585, 169.77487988,
#        167.3555775 , 169.4339704 , 150.11786915, 167.51831371,
#        182.5469301 , 179.27474573, 189.59204328, 148.76640894,
#        169.14591215, 146.92214083, 175.21248626, 172.09341756,
#        159.06162229, 152.04619947, 185.86507728, 158.00140911,
#        159.01021418, 172.77621016, 186.82432288, 175.44102061,
#        173.30031663, 180.09161378, 172.56346928, 160.80026924,
#        172.82168306, 173.12296002, 180.27822615, 186.99256862,
#        170.11387284, 174.32273677, 169.15135837, 179.09449397,
#        160.16233801, 157.29900059, 164.51192664, 176.04457314,
#        168.94379442, 171.99919025, 182.04694009, 151.82801976,
#        166.08513182, 164.85891149])

# %%
plt.hist(x)
# Out:
# (array([ 2.,  5., 13., 33., 60., 53., 44., 23., 14.,  3.]),
#  array([140.72885669, 146.21822851, 151.70760032, 157.19697213,
#         162.68634394, 168.17571576, 173.66508757, 179.15445938,
#         184.64383119, 190.13320301, 195.62257482]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# PIE

# %%
x=np.array([1,2,3,4])
plt.pie(x)
plt.show()

# %%
x = np.array([1, 2, 3, 4, 5])
label = np.array(['o2', 'co2', 'n', 'others', 'argon'])

plt.pie(x, labels=label, startangle=90,myexplode)
plt.show()
# Out:
#   Cell In[35], line 4
#     plt.pie(x, labels=label, startangle=90,myexplode)
#                                                     ^
# SyntaxError: positional argument follows keyword argument

# %%
gases = ['n2', 'o2', 'co2']
percentages = [78, 21, 1]
myexplode=[0.2,0,0]
plt.pie(percentages, labels=gases, startangle=90, explode=myexplode, shadow=True)
plt.title("Gases and Their Percentages")
plt.show()

# %%
gases = ['n2', 'o2', 'co2','others']
percentages = [70, 21, 1,8]
myexplode=[0,0,0.6,0]
color=['red', 'green', 'grey','pink']
plt.pie(percentages, labels=gases, startangle=90, explode=myexplode, shadow=True, colors=color)
plt.title("Gases and Their Percentages")
plt.show()

# %%
gases = ['n2', 'o2', 'co2','others']
percentages = [70, 21, 1,8]
myexplode=[0,0,0,0.5]
color=['red', 'green', 'grey','pink']
# autopct displays the percentage value on each slice of the pie chart
plt.pie(percentages, labels=gases, startangle=90, explode=myexplode, shadow=True, colors=color, autopct='%1.1f')
plt.title("Gases and Their Percentages")
plt.show()

# %%
gases=["NITROGEN","OXYGEN","ARGON","CARBON DIOXIDE","OTHERS"]
percentages=[78.09,20.95,0.93,0.04,0.01]
colors=['skyblue','red','yellow','silver','gray']
explode = [0, 0.1, 0, 0, 0]

plt.figure(figsize=(8, 8))
plt.pie(
    percentages,
    labels=gases,
    colors=colors,
    explode=explode,
    autopct='%1.2f%%',
    startangle=90,
    shadow=True
)
plt.title("Composition of Air")
plt.show()
